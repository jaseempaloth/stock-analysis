# %%
import pandas as pd

# %%
df = pd.read_csv('MW-NIFTY-100-26-Sep-2024.csv')
df
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0    NIFTY 100  27,068.30  27,153.00  27,056.85      27,051.65  27,141.50
# 1         VEDL     484.55     504.90     477.00         479.85     502.50
# 2       MARUTI  12,835.00  13,411.00  12,830.00      12,785.30  13,350.00
# 3    MOTHERSON     204.70     213.00     202.61         205.48     211.54
# 4        TRENT   7,724.90   7,939.90   7,710.55       7,614.90   7,830.00
# ..         ...        ...        ...        ...            ...        ...
# 96       CIPLA   1,643.20   1,652.45   1,602.30       1,643.20   1,611.10
# 97         ABB   8,214.00   8,214.00   7,962.55       8,178.35   7,995.50
# 98     SIEMENS   7,210.00   7,237.85   6,990.10       7,177.00   7,011.00
# 99      ZOMATO     285.40     285.90     278.50         285.40     278.65
# 100    HAVELLS   2,061.60   2,061.60   1,991.85       2,061.60   2,000.50
#
#     INDICATIVE CLOSE \n  CHNG \n  %CHNG \n VOLUME \n(shares)  \
# ...

# %%
open_high = df[df['OPEN \n'] == df['LOW \n']]

# %%
open_high
# Out:
#     SYMBOL \n   OPEN \n   HIGH \n    LOW \n PREV. CLOSE \n    LTP \n  \
# 19  NESTLEIND  2,707.95  2,762.45  2,707.95       2,697.35  2,734.45
# 59   ADANIENT  3,085.00  3,148.00  3,085.00       3,105.10  3,108.65
# 61        TCS  4,260.00  4,316.80  4,260.00       4,274.75  4,278.10
#
#    INDICATIVE CLOSE \n  CHNG \n  %CHNG \n VOLUME \n(shares)  \
# 19                   -    37.10      1.38          7,03,717
# 59                   -     3.55      0.11          9,33,022
# 61                   -     3.35      0.08         28,52,115
#
#    VALUE \n (₹ Crores)  52W H \n  52W L \n  30 D   %CHNG \n  \
# 19              192.30  2,769.30  2,225.52             7.06
# 59              290.56  3,743.90  2,142.00             1.18
# 61            1,222.88  4,592.25  3,311.00            -5.06
#
#    365 D % CHNG \n 26-Sep-2023
# 19                      -88.28
# 59                       26.33
# 61                       19.22

# %%
open_low = df[df['OPEN \n'] == df['HIGH \n']]
open_low
# Out:
#     SYMBOL \n   OPEN \n   HIGH \n    LOW \n PREV. CLOSE \n    LTP \n  \
# 85       NTPC    437.95    437.95    430.55         436.10    430.95
# 87        PFC    485.00    485.00    475.15         483.45    477.50
# 95      DMART  5,313.45  5,313.45  5,164.00       5,265.50  5,168.05
# 97        ABB  8,214.00  8,214.00  7,962.55       8,178.35  7,995.50
# 100   HAVELLS  2,061.60  2,061.60  1,991.85       2,061.60  2,000.50
#
#     INDICATIVE CLOSE \n  CHNG \n  %CHNG \n VOLUME \n(shares)  \
# 85                    -    -5.15     -1.18       1,20,27,790
# 87                    -    -5.95     -1.23         59,00,300
# 95                    -   -97.45     -1.85          2,35,331
# 97                    -  -182.85     -2.24          1,62,437
# 100                   -   -61.10     -2.96          8,60,216
#
#     VALUE \n (₹ Crores)  52W H \n  52W L \n  30 D   %CHNG \n  \
# 85               520.41    437.95    227.75             5.12
# ...
